# %% [markdown]
# # Problem Statement

# %% [markdown]
# Ask a home buyer to describe their dream house, and they probably won't begin with the height of the basement ceiling or the proximity to an east-west railroad. But this playground competition's dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.
#
# With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this competition challenges you to predict the final price of each home.

# %% [markdown]
# # Feature Description

# %% [markdown]
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
#        RP	Residential Low Density Park
#        RM	Residential Medium Density
#
# LotFrontage: Linear feet of street connected to property
#
# LotArea: Lot size in square feet
#
# Street: Type of road access to property
#
#        Grvl	Gravel
#        Pave	Paved
#
# Alley: Type of alley access to property
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access
#
# LotShape: General shape of property
#
#        Reg	Regular
#        IR1	Slightly irregular
#        IR2	Moderately Irregular
#        IR3	Irregular
#
# LandContour: Flatness of the property
#
#        Lvl	Near Flat/Level
#        Bnk	Banked - Quick and significant rise from street grade to building
#        HLS	Hillside - Significant slope from side to side
#        Low	Depression
#
# Utilities: Type of utilities available
#
#        AllPub	All public Utilities (E,G,W,& S)
#        NoSewr	Electricity, Gas, and Water (Septic Tank)
#        NoSeWa	Electricity and Gas Only
#        ELO	Electricity only
#
# LotConfig: Lot configuration
#
#        Inside	Inside lot
#        Corner	Corner lot
#        CulDSac	Cul-de-sac
#        FR2	Frontage on 2 sides of property
#        FR3	Frontage on 3 sides of property
#
# LandSlope: Slope of property
#
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
#
# Neighborhood: Physical locations within Ames city limits
#
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker
#
# Condition1: Proximity to various conditions
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# Condition2: Proximity to various conditions (if more than one is present)
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# BldgType: Type of dwelling
#
#        1Fam	Single-family Detached
#        2FmCon	Two-family Conversion; originally built as one-family dwelling
#        Duplx	Duplex
#        TwnhsE	Townhouse End Unit
#        TwnhsI	Townhouse Inside Unit
#
# HouseStyle: Style of dwelling
#
#        1Story	One story
#        1.5Fin	One and one-half story: 2nd level finished
#        1.5Unf	One and one-half story: 2nd level unfinished
#        2Story	Two story
#        2.5Fin	Two and one-half story: 2nd level finished
#        2.5Unf	Two and one-half story: 2nd level unfinished
#        SFoyer	Split Foyer
#        SLvl	Split Level
#
# OverallQual: Rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# OverallCond: Rates the overall condition of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# YearBuilt: Original construction date
#
# YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)
#
# RoofStyle: Type of roof
#
#        Flat	Flat
#        Gable	Gable
#        Gambrel	Gabrel (Barn)
#        Hip	Hip
#        Mansard	Mansard
#        Shed	Shed
#
# RoofMatl: Roof material
#
#        ClyTile	Clay or Tile
#        CompShg	Standard (Composite) Shingle
#        Membran	Membrane
#        Metal	Metal
#        Roll	Roll
#        Tar&Grv	Gravel & Tar
#        WdShake	Wood Shakes
#        WdShngl	Wood Shingles
#
# Exterior1st: Exterior covering on house
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# Exterior2nd: Exterior covering on house (if more than one material)
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# MasVnrType: Masonry veneer type
#
#        BrkCmn	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        None	None
#        Stone	Stone
#
# MasVnrArea: Masonry veneer area in square feet
#
# ExterQual: Evaluates the quality of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# ExterCond: Evaluates the present condition of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# Foundation: Type of foundation
#
#        BrkTil	Brick & Tile
#        CBlock	Cinder Block
#        PConc	Poured Contrete
#        Slab	Slab
#        Stone	Stone
#        Wood	Wood
#
# BsmtQual: Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement
#
# BsmtCond: Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement
#
# BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
#
# BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF1: Type 1 finished square feet
#
# BsmtFinType2: Rating of basement finished area (if multiple types)
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF2: Type 2 finished square feet
#
# BsmtUnfSF: Unfinished square feet of basement area
#
# TotalBsmtSF: Total square feet of basement area
#
# Heating: Type of heating
#
#        Floor	Floor Furnace
#        GasA	Gas forced warm air furnace
#        GasW	Gas hot water or steam heat
#        Grav	Gravity furnace
#        OthW	Hot water or steam heat other than gas
#        Wall	Wall furnace
#
# HeatingQC: Heating quality and condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# CentralAir: Central air conditioning
#
#        N	No
#        Y	Yes
#
# Electrical: Electrical system
#
#        SBrkr	Standard Circuit Breakers & Romex
#        FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
#        FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
#        FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
#        Mix	Mixed
#
# 1stFlrSF: First Floor square feet
#
# 2ndFlrSF: Second floor square feet
#
# LowQualFinSF: Low quality finished square feet (all floors)
#
# GrLivArea: Above grade (ground) living area square feet
#
# BsmtFullBath: Basement full bathrooms
#
# BsmtHalfBath: Basement half bathrooms
#
# FullBath: Full bathrooms above grade
#
# HalfBath: Half baths above grade
#
# Bedroom: Bedrooms above grade (does NOT include basement bedrooms)
#
# Kitchen: Kitchens above grade
#
# KitchenQual: Kitchen quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
#        Typ	Typical Functionality
#        Min1	Minor Deductions 1
#        Min2	Minor Deductions 2
#        Mod	Moderate Deductions
#        Maj1	Major Deductions 1
#        Maj2	Major Deductions 2
#        Sev	Severely Damaged
#        Sal	Salvage only
#
# Fireplaces: Number of fireplaces
#
# FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace
#
# GarageType: Garage location
#
#        2Types	More than one type of garage
#        Attchd	Attached to home
#        Basment	Basement Garage
#        BuiltIn	Built-In (Garage part of house - typically has room above garage)
#        CarPort	Car Port
#        Detchd	Detached from home
#        NA	No Garage
#
# GarageYrBlt: Year garage was built
#
# GarageFinish: Interior finish of the garage
#
#        Fin	Finished
#        RFn	Rough Finished
#        Unf	Unfinished
#        NA	No Garage
#
# GarageCars: Size of garage in car capacity
#
# GarageArea: Size of garage in square feet
#
# GarageQual: Garage quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# GarageCond: Garage condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# PavedDrive: Paved driveway
#
#        Y	Paved
#        P	Partial Pavement
#        N	Dirt/Gravel
#
# WoodDeckSF: Wood deck area in square feet
#
# OpenPorchSF: Open porch area in square feet
#
# EnclosedPorch: Enclosed porch area in square feet
#
# 3SsnPorch: Three season porch area in square feet
#
# ScreenPorch: Screen porch area in square feet
#
# PoolArea: Pool area in square feet
#
# PoolQC: Pool quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        NA	No Pool
#
# **Fence: Fence quality**
#
# 1. GdPrv	Good Privacy
# 2. MnPrv	Minimum Privacy
# 3. GdWo	    Good Wood
# 4. MnWw	    Minimum Wood/Wire
# 5. ***NA	No Fence***
#
# **MiscFeature: Miscellaneous feature not covered in other categories**
#
# 1. Elev	Elevator
# 2. Gar2	2nd Garage (if not described in garage section)
# 3. Othr	Other
# 4. Shed	Shed (over 100 SF)
# 5. TenC	Tennis Court
# 6. ***NA	None***
#
# **MiscVal: Dollar Value of miscellaneous feature**
#
# **MoSold: Month Sold (MM)**
#
# **YrSold: Year Sold (YYYY)**
#
# **SaleType: Type of sale**
#
# 1. WD 	Warranty Deed - Conventional
# 2. CWD	Warranty Deed - Cash
# 3. VWD	Warranty Deed - VA Loan
# 4. New	Home just constructed and sold
# 5. COD	Court Officer Deed/Estate
# 6. Con	Contract 15% Down payment regular terms
# 7. ConLw	Contract Low Down payment and low interest
# 8. ConLI	Contract Low Interest
# 9. ConLD	Contract Low Down
# 10. Oth	Other
#
# **SaleCondition: Condition of sale**
#
# 1. Normal	Normal Sale
# 2. Abnorml	Abnormal Sale -  trade, foreclosure, short sale
# 3. AdjLand	Adjoining Land Purchase
# 4. Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage unit
# 5. Family	Sale between family members
# 6. Partial	Home was not completed when last assessed (associated with New Homes)

# %% [markdown]
# # Importing required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import warnings
warnings.filterwarnings("ignore")
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.compose import ColumnTransformer
import sklearn.metrics as metrics
from sklearn.model_selection import KFold, cross_validate,cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, RobustScaler,Normalizer,MinMaxScaler,OrdinalEncoder

# %%
train=pd.read_csv('Datasets\\House Price\\train.csv')
train.shape
# Out:
# (1460, 81)

# %%
test=pd.read_csv('Datasets\\House Price\\test.csv')
test.shape
# Out:
# (1459, 80)

# %%
# Checking null counts in train and test data

train_null_counts=pd.DataFrame(train.isnull().sum(),columns=['train_null_count'])
train_null_counts=train_null_counts.loc[train_null_counts.train_null_count>0]
test_null_counts=pd.DataFrame(test.isnull().sum(),columns=['test_null_count'])
test_null_counts=test_null_counts.loc[test_null_counts.test_null_count>0]
null_counts=test_null_counts.join(train_null_counts).fillna(0)
null_counts['train_null_%']=round((null_counts['train_null_count']/train.shape[0])*100,2)
null_counts['test_null_%']=round((null_counts['test_null_count']/test.shape[0])*100,2)
null_counts
# Out:
#               test_null_count  train_null_count  train_null_%  test_null_%
# MSZoning                    4               0.0          0.00         0.27
# LotFrontage               227             259.0         17.74        15.56
# Alley                    1352            1369.0         93.77        92.67
# Utilities                   2               0.0          0.00         0.14
# Exterior1st                 1               0.0          0.00         0.07
# Exterior2nd                 1               0.0          0.00         0.07
# MasVnrType                 16               8.0          0.55         1.10
# MasVnrArea                 15               8.0          0.55         1.03
# BsmtQual                   44              37.0          2.53         3.02
# BsmtCond                   45              37.0          2.53         3.08
# BsmtExposure               44              38.0          2.60         3.02
# ...

# %% [markdown]
# # Updating Missing Values in Train Data

# %%
# From feature description we can see that 
# NA in Alley means "No Access to Alley". Similary,
# NA in FireplaceQu means "No Fireplace",
# NA in PoolQC means "No Pool"
# NA in Fence means "No Fence"
# NA in MiscFeature means "No MiscFeature"
# NA in GarageQual,GarageCond,GarageType and GarageFinish means "No Garage"
# NA in GarageYrBlt is updated with YearBuilt as for most of the data points YearBuilt and GarageYrBlt is same as seen above.
# NA in BsmtQual,BsmtCond,BsmtExposure,BsmtFinType1,BsmtFinType2 means "No Basement"

train['Alley']=train.Alley.apply(lambda x: 'No Alley' if pd.isnull(x) else x)
train['FireplaceQu']=train.FireplaceQu.apply(lambda x: 'No Fireplace' if pd.isnull(x) else x)
train['PoolQC']=train.PoolQC.apply(lambda x: 'No Pool' if pd.isnull(x) else x)
train['Fence']=train.Fence.apply(lambda x: 'No Fence' if pd.isnull(x) else x)
train['MiscFeature']=train.MiscFeature.apply(lambda x: 'No MiscFeature' if pd.isnull(x) else x)
train['GarageQual']=train.GarageQual.apply(lambda x: 'No Garage' if pd.isnull(x) else x)
train['GarageCond']=train.GarageCond.apply(lambda x: 'No Garage' if pd.isnull(x) else x)
train['GarageType']=train.GarageType.apply(lambda x: 'No Garage' if pd.isnull(x) else x)
train['GarageFinish']=train.GarageFinish.apply(lambda x: 'No Garage' if pd.isnull(x) else x)
train['GarageYrBlt']=train.GarageYrBlt.apply(lambda x:0 if pd.isnull(x) else x)
train['BsmtQual']=train.BsmtQual.apply(lambda x: 'No Basement' if pd.isnull(x) else x)
train['BsmtCond']=train.BsmtCond.apply(lambda x: 'No Basement' if pd.isnull(x) else x)
train['BsmtFinType1']=train.BsmtFinType1.apply(lambda x: 'No Basement' if pd.isnull(x) else x)
train['BsmtFinType2']=train.BsmtFinType2.apply(lambda x: 'No Basement' if pd.isnull(x) else x)

# %%
train.loc[(train.BsmtExposure.isnull()==True) & (train.BsmtQual=='Gd') & (train.BsmtCond=='TA')
         & (train.BsmtFinType1=='Unf') & (train.BsmtFinType2=='Unf'),['BsmtQual','BsmtCond','BsmtExposure',
                             'BsmtFinType1','BsmtFinType2']]
# Out:
#     BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2
# 948       Gd       TA          NaN          Unf          Unf

# %%
basement_group=train.groupby(['BsmtQual','BsmtCond','BsmtFinType1','BsmtFinType2','BsmtExposure']).count()['Id']
basement_group.loc['Gd'].loc['TA'].loc['Unf'].loc['Unf']
# Out:
# BsmtExposure
# Av     26
# Gd      5
# Mn     10
# No    136
# Name: Id, dtype: int64

# %%
train['BsmtExposure']=train.BsmtExposure.apply(lambda x: 'No Basement' if pd.isnull(x) else x)

# %% [markdown]
# The difference is that with solid masonry, the brick is holding up the house. With brick veneer, the house is holding up the brick. Ex-Behind the brick veneer is a wood frame wall which is actually holding up the house.

# %%
print(train['Electrical'].value_counts())
print('********************************')
print(train['MasVnrType'].value_counts())
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64
# ********************************
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
train.describe()[['LotFrontage','MasVnrArea']]
# Out:
#        LotFrontage   MasVnrArea
# count  1201.000000  1452.000000
# mean     70.049958   103.685262
# std      24.284752   181.066207
# min      21.000000     0.000000
# 25%      59.000000     0.000000
# 50%      69.000000     0.000000
# 75%      80.000000   166.000000
# max     313.000000  1600.000000

# %%
# The mode in Electrical is "SBrkr" hence updating missing value as "SBrkr" in Electrical.
# The difference between mean and median of LotFrontage is very small hence updating missing values in LotFrontage with median i.e 69. 
# Since house with MasVnrType as NA has MasVnrArea also as NA. Hence we would be updating MasVnrArea as 0 and MasVnrType as None
# for missing values in MasVnrType and MasVnrArea.

train['Electrical']=train.Electrical.apply(lambda x: 'SBrkr' if pd.isnull(x) else x)
train['MasVnrArea']=train.MasVnrArea.apply(lambda x: 0 if pd.isnull(x) else x)
train['MasVnrType']=train.MasVnrType.apply(lambda x: 'None' if pd.isnull(x) else x)
train['LotFrontage']=train.LotFrontage.apply(lambda x: 69 if pd.isnull(x) else x)

# %% [markdown]
# # Updating Missing Values in Test Data

# %%
# From feature description we can see that 
# NA in Alley means "No Access to Alley". Similary,
# NA in FireplaceQu means "No Fireplace",
# NA in PoolQC means "No Pool"
# NA in Fence means "No Fence"
# NA in MiscFeature means "No MiscFeature"

test['Alley']=test.Alley.apply(lambda x: 'No Alley' if pd.isnull(x) else x)
test['FireplaceQu']=test.FireplaceQu.apply(lambda x: 'No Fireplace' if pd.isnull(x) else x)
test['PoolQC']=test.PoolQC.apply(lambda x: 'No Pool' if pd.isnull(x) else x)
test['Fence']=test.Fence.apply(lambda x: 'No Fence' if pd.isnull(x) else x)
test['MiscFeature']=test.MiscFeature.apply(lambda x: 'No MiscFeature' if pd.isnull(x) else x)

# %% [markdown]
# ###### Analyzing NA is BsmtQual,BsmtCond,BsmtExposure,BsmtFinType1,BsmtFinType2 columns

# %%
test.loc[(test.BsmtFinType1.isnull()==False) & (test.BsmtFinType2.isnull()==False) & (test.BsmtQual.isnull()),['BsmtQual','BsmtCond','BsmtExposure',
                             'BsmtFinType1','BsmtFinType2']]
# Out:
#     BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2
# 757      NaN       Fa           No          Unf          Unf
# 758      NaN       TA           No          Unf          Unf

# %%
basement_group=test.groupby(['BsmtExposure','BsmtCond','BsmtFinType1','BsmtFinType2','BsmtQual',]).count()['Id']
basement_group.loc['No'].loc['Fa'].loc['Unf'].loc['Unf']
# Out:
# BsmtQual
# Fa     8
# Gd     1
# TA    15
# Name: Id, dtype: int64

# %%
test.loc[(test.BsmtFinType1.isnull()==False) & (test.BsmtFinType2.isnull()==False) & (test.BsmtCond.isnull()),['BsmtQual','BsmtCond','BsmtExposure',
                             'BsmtFinType1','BsmtFinType2']]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2
# 580        Gd      NaN           Mn          GLQ          Rec
# 725        TA      NaN           No          BLQ          Unf
# 1064       TA      NaN           Av          ALQ          Unf

# %%
basement_group=test.groupby(['BsmtExposure','BsmtQual','BsmtFinType1','BsmtFinType2','BsmtCond']).count()['Id']
basement_group.loc['Av'].loc['TA'].loc['ALQ'].loc['Unf']
# Out:
# BsmtCond
# TA    14
# Name: Id, dtype: int64

# %%
test.loc[(test.BsmtFinType1.isnull()==False) & (test.BsmtFinType2.isnull()==False) & (test.BsmtExposure.isnull()),['BsmtQual','BsmtCond','BsmtExposure',
                             'BsmtFinType1','BsmtFinType2']]
# Out:
#     BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2
# 27        Gd       TA          NaN          Unf          Unf
# 888       Gd       TA          NaN          Unf          Unf

# %%
basement_group=test.groupby(['BsmtCond','BsmtQual','BsmtFinType1','BsmtFinType2','BsmtExposure']).count()['Id']
basement_group.loc['TA'].loc['Gd'].loc['Unf'].loc['Unf']
# Out:
# BsmtExposure
# Av     32
# Gd      5
# Mn     12
# No    119
# Name: Id, dtype: int64

# %%
# From above observation if BsmtQual,BsmtCond,BsmtExposure,BsmtFinType1,BsmtFinType2 all have NA then its "No Basement" else if 
# BsmtQual is NA but others are not then NA is replaced with "TA". Similarly, BsmtCond is NA but others are not then NA is replaced with "TA",
# BsmtExposure is NA but others are not then NA is replaced with "No".

test['BsmtQual']=test[['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1',
                         'BsmtFinType2']].apply(lambda x: 'No Basement' if pd.isnull(x['BsmtQual']) and pd.isnull(x['BsmtCond']) and
                                                pd.isnull(x['BsmtExposure']) and pd.isnull(x['BsmtFinType1']) and 
                                                pd.isnull(x['BsmtFinType2']) else 'TA' if pd.isnull(x['BsmtQual']) and (np.all(pd.notnull(x['BsmtCond'])))
                                                and np.all((pd.notnull(x['BsmtExposure']))) and np.all((pd.notnull(x['BsmtFinType1']))) and 
                                                np.all((pd.notnull(x['BsmtFinType2']))) else x['BsmtQual'], axis=1)
test['BsmtCond']=test[['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1',
                         'BsmtFinType2']].apply(lambda x: 'No Basement' if (x['BsmtQual']=='No Basement') and pd.isnull(x['BsmtCond']) and
                                                pd.isnull(x['BsmtExposure']) and pd.isnull(x['BsmtFinType1']) and 
                                                pd.isnull(x['BsmtFinType2']) else 'TA' if pd.isnull(x['BsmtCond']) and np.all((pd.notnull(x['BsmtQual'])))
                                                and np.all((pd.notnull(x['BsmtExposure']))) and np.all((pd.notnull(x['BsmtFinType1']))) and 
                                                np.all((pd.notnull(x['BsmtFinType2']))) else x['BsmtCond'], axis=1)
test['BsmtExposure']=test[['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1',
                         'BsmtFinType2']].apply(lambda x: 'No Basement' if (x['BsmtQual']=='No Basement') and (x['BsmtCond']=='No Basement') and
                                                pd.isnull(x['BsmtExposure']) and pd.isnull(x['BsmtFinType1']) and 
                                                pd.isnull(x['BsmtFinType2']) else 'No' if pd.isnull(x['BsmtExposure']) and np.all((pd.notnull(x['BsmtCond'])))
                                                and np.all((pd.notnull(x['BsmtQual']))) and np.all((pd.notnull(x['BsmtFinType1']))) and 
                                                np.all((pd.notnull(x['BsmtFinType2']))) else x['BsmtExposure'], axis=1)
test['BsmtFinType1']=test.BsmtFinType1.apply(lambda x: 'No Basement' if pd.isnull(x) else x)
test['BsmtFinType2']=test.BsmtFinType2.apply(lambda x: 'No Basement' if pd.isnull(x) else x)

# %% [markdown]
# ###### Analyzing NA is GarageQual,GarageCond,GarageType,GarageYrBlt and GarageFinish columns

# %%
test.loc[(test.GarageType.isnull()==False) & (test.GarageCond.isnull()) & test.GarageQual.isnull() & test.GarageFinish.isnull()
         & test.GarageYrBlt.isnull(),['GarageType','GarageCond','GarageQual','GarageFinish','GarageYrBlt']]
# Out:
#      GarageType GarageCond GarageQual GarageFinish  GarageYrBlt
# 666      Detchd        NaN        NaN          NaN          NaN
# 1116     Detchd        NaN        NaN          NaN          NaN

# %%
garage_group=test.groupby(['GarageType','GarageCond','GarageQual','GarageFinish','GarageYrBlt']).count()
garage_group.loc[garage_group['Id']==10,'Id']
# Out:
# GarageType  GarageCond  GarageQual  GarageFinish  GarageYrBlt
# Attchd      TA          TA          Fin           1997.0         10
#                                     RFn           1977.0         10
#                                                   2002.0         10
# Detchd      TA          TA          Unf           1939.0         10
#                                                   1950.0         10
# Name: Id, dtype: int64

# %%
test['GarageQual']=test[['GarageType','GarageCond','GarageQual','GarageFinish',
                         'GarageYrBlt']].apply(lambda x: 'No Garage' if pd.isnull(x['GarageType']) and  pd.isnull(x['GarageCond']) and
                                               pd.isnull(x['GarageQual']) and pd.isnull(x['GarageFinish']) and 
                                               pd.isnull(x['GarageYrBlt']) else 'TA' if (x['GarageType']=='Detchd') 
                                               and  pd.isnull(x['GarageCond']) and pd.isnull(x['GarageQual']) and pd.isnull(x['GarageFinish']) and 
                                               pd.isnull(x['GarageYrBlt']) else x['GarageQual'], axis=1)

test['GarageCond']=test[['GarageType','GarageCond','GarageQual','GarageFinish',
                         'GarageYrBlt']].apply(lambda x: 'No Garage' if pd.isnull(x['GarageType']) and  pd.isnull(x['GarageCond']) and
                                               (x['GarageQual']=='No Garage') and pd.isnull(x['GarageFinish']) and 
                                               pd.isnull(x['GarageYrBlt']) else 'TA' if (x['GarageType']=='Detchd') 
                                               and  pd.isnull(x['GarageCond']) and np.all(pd.notnull(x['GarageQual'])) and pd.isnull(x['GarageFinish']) and 
                                               pd.isnull(x['GarageYrBlt'])  else x['GarageCond'], axis=1)

test['GarageType']=test[['GarageType','GarageCond','GarageQual','GarageFinish',
                         'GarageYrBlt']].apply(lambda x: 'No Garage' if pd.isnull(x['GarageType']) and  (x['GarageCond']=='No Garage') and
                                               (x['GarageQual']=='No Garage') and pd.isnull(x['GarageFinish']) and 
                                               pd.isnull(x['GarageYrBlt']) else x['GarageType'], axis=1)

test['GarageFinish']=test[['GarageType','GarageCond','GarageQual','GarageFinish',
                         'GarageYrBlt']].apply(lambda x: 'No Garage' if (x['GarageType']=='No Garage') and  (x['GarageCond']=='No Garage') and
                                               (x['GarageQual']=='No Garage') and pd.isnull(x['GarageFinish']) and 
                                               pd.isnull(x['GarageYrBlt']) else 'Unf' if (x['GarageType']=='Detchd') 
                                               and  np.all(pd.notnull(x['GarageCond'])) and np.all(pd.notnull(x['GarageQual'])) and pd.isnull(x['GarageFinish']) and 
                                               pd.isnull(x['GarageYrBlt']) else x['GarageFinish'], axis=1)

test['GarageYrBlt']=test[['GarageType','GarageCond','GarageQual','GarageFinish',
                         'GarageYrBlt']].apply(lambda x: 0 if (x['GarageType']=='No Garage') and  (x['GarageCond']=='No Garage') and
                                               (x['GarageQual']=='No Garage') and (x['GarageFinish']=='No Garage') and 
                                               pd.isnull(x['GarageYrBlt']) else 1950 if (x['GarageType']=='Detchd') 
                                               and  np.all(pd.notnull(x['GarageCond'])) and np.all(pd.notnull(x['GarageQual'])) and np.all(pd.notnull(x['GarageFinish'])) and 
                                               pd.isnull(x['GarageYrBlt']) else x['GarageYrBlt'], axis=1)

# %%
test.describe()[['LotFrontage','MasVnrArea']]
# Out:
#        LotFrontage   MasVnrArea
# count  1232.000000  1444.000000
# mean     68.580357   100.709141
# std      22.376841   177.625900
# min      21.000000     0.000000
# 25%      58.000000     0.000000
# 50%      67.000000     0.000000
# 75%      80.000000   164.000000
# max     200.000000  1290.000000

# %%
# Checking NA in MasVnrType which has MasVnrArea.
test.loc[(test.MasVnrArea.notnull()) & (test.MasVnrType.isnull()),['MasVnrType','MasVnrArea']]
# Out:
#      MasVnrType  MasVnrArea
# 1150        NaN       198.0

# %%
# Checking mode of the MasVnrType for MasVnrArea 198 
test.loc[(test.MasVnrArea==198) ,['MasVnrType','MasVnrArea']]
# Out:
#      MasVnrType  MasVnrArea
# 245       Stone       198.0
# 421     BrkFace       198.0
# 1085      Stone       198.0
# 1150        NaN       198.0
# 1372    BrkFace       198.0
# 1442      Stone       198.0

# %%
# The difference between mean and median of LotFrontage is very small hence updating missing values in LotFrontage with median i.e 67. 
# Since house with MasVnrType as NA has MasVnrArea also as NA. Hence we would be updating MasVnrArea as 0 and MasVnrType as None
# for missing values in MasVnrType and MasVnrArea.

test['MasVnrArea']=test.MasVnrArea.apply(lambda x: 0 if pd.isnull(x) else x)
test['MasVnrType']=test[['MasVnrType','MasVnrArea']].apply(lambda x: 'None' if pd.isnull(x['MasVnrArea']) 
                                                           and pd.isnull(x['MasVnrType']) else 'Stone' 
                                                           if pd.isnull(x['MasVnrType']) and np.all(pd.notnull(x['MasVnrArea'])) else x,axis=1)
test['LotFrontage']=test.LotFrontage.apply(lambda x: 67 if pd.isnull(x) else x)

# %%
test.loc[test.GarageCars.isnull(),['GarageType','GarageCond','GarageQual','GarageFinish',
                         'GarageYrBlt','GarageCars','GarageArea']]
# Out:
#      GarageType GarageCond GarageQual GarageFinish  GarageYrBlt  GarageCars  \
# 1116     Detchd         TA         TA          Unf       1950.0         NaN
#
#       GarageArea
# 1116         NaN

# %%
test.loc[(test.GarageType=='Detchd') & (test.GarageCond=='TA') & (test.GarageQual=='TA') 
         & (test.GarageFinish=='Unf') & (test.GarageYrBlt==1950),['GarageType','GarageCond','GarageQual','GarageFinish',
                         'GarageFinish','GarageCars','GarageArea','GarageYrBlt']]
# Out:
#      GarageType GarageCond GarageQual GarageFinish GarageFinish  GarageCars  \
# 67       Detchd         TA         TA          Unf          Unf         1.0
# 81       Detchd         TA         TA          Unf          Unf         1.0
# 136      Detchd         TA         TA          Unf          Unf         2.0
# 141      Detchd         TA         TA          Unf          Unf         1.0
# 352      Detchd         TA         TA          Unf          Unf         1.0
# 361      Detchd         TA         TA          Unf          Unf         3.0
# 628      Detchd         TA         TA          Unf          Unf         1.0
# 651      Detchd         TA         TA          Unf          Unf         1.0
# 666      Detchd         TA         TA          Unf          Unf         1.0
# 995      Detchd         TA         TA          Unf          Unf         1.0
# 1003     Detchd         TA         TA          Unf          Unf         1.0
# ...

# %%
test.loc[(test.GarageType=='Detchd') & (test.GarageCond=='TA') & (test.GarageQual=='TA') 
         & (test.GarageFinish=='Unf') & (test.GarageYrBlt==1950),'GarageArea'].mean()
# Out:
# 388.3636363636364

# %%
# Based on above obsercation filling NA in GarageCars with 1 and GarageArea with 388

test['GarageCars']=test.GarageCars.apply(lambda x: 1 if pd.isnull(x) else x)
test['GarageArea']=test.GarageArea.apply(lambda x: 360 if pd.isnull(x) else x)

# %%
test.Utilities.value_counts()
# Out:
# AllPub    1457
# Name: Utilities, dtype: int64

# %%
test['Utilities']=test.Utilities.apply(lambda x: 'AllPub' if pd.isnull(x) else x)

# %%
test.Exterior1st.value_counts()
# Out:
# VinylSd    510
# MetalSd    230
# HdBoard    220
# Wd Sdng    205
# Plywood    113
# CemntBd     65
# BrkFace     37
# WdShing     30
# AsbShng     24
# Stucco      18
# BrkComm      4
# AsphShn      1
# CBlock       1
# Name: Exterior1st, dtype: int64

# %%
# Mode of VinylSd is highest hence filling NA in Exterior1st and Exterior2nd with VinylSd

test['Exterior1st']=test.Exterior1st.apply(lambda x: 'VinylSd' if pd.isnull(x) else x)
test['Exterior2nd']=test.Exterior2nd.apply(lambda x: 'VinylSd' if pd.isnull(x) else x)

# %%
test.SaleType.value_counts()
# Out:
# WD       1258
# New       117
# COD        44
# ConLD      17
# CWD         8
# ConLI       4
# Oth         4
# Con         3
# ConLw       3
# Name: SaleType, dtype: int64

# %%
test.loc[test.SaleType.isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street     Alley  \
# 1029  2490          20       RL         85.0    13770   Pave  No Alley
#
#      LotShape LandContour Utilities  ... ScreenPorch PoolArea   PoolQC  \
# 1029      Reg         Lvl    AllPub  ...           0        0  No Pool
#
#          Fence     MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 1029  No Fence  No MiscFeature       0     10    2007       NaN         Normal
#
# [1 rows x 80 columns]

# %%
saletype_group=test.groupby(['YrSold','MoSold','SaleType','SaleCondition']).count()['Id']
saletype_group.loc[2006].loc[10]
# Out:
# SaleType  SaleCondition
# ConLD     Normal            1
# New       Partial           4
# WD        Abnorml           5
#           AdjLand           1
#           Family            1
#           Normal           13
# Name: Id, dtype: int64

# %%
# Based on above observation SaleType is WD

test['SaleType']=test.SaleType.apply(lambda x: 'WD' if pd.isnull(x) else x)

# %%
test.loc[test.BsmtFullBath.isnull(),['BsmtFinSF1','BsmtFinSF2','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1',
                         'BsmtFinType2','BsmtHalfBath','BsmtFullBath','TotalBsmtSF','BsmtUnfSF']]
# Out:
#      BsmtFinSF1  BsmtFinSF2     BsmtQual     BsmtCond BsmtExposure  \
# 660         NaN         NaN  No Basement  No Basement  No Basement
# 728         0.0         0.0  No Basement  No Basement  No Basement
#
#     BsmtFinType1 BsmtFinType2  BsmtHalfBath  BsmtFullBath  TotalBsmtSF  \
# 660  No Basement  No Basement           NaN           NaN          NaN
# 728  No Basement  No Basement           NaN           NaN          0.0
#
#      BsmtUnfSF
# 660        NaN
# 728        0.0

# %%
test.loc[(test.BsmtQual=='No Basement'),['BsmtFinSF1','BsmtFinSF2','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1',
                         'BsmtFinType2','BsmtHalfBath','BsmtFullBath','TotalBsmtSF','BsmtUnfSF']].head()
# Out:
#      BsmtFinSF1  BsmtFinSF2     BsmtQual     BsmtCond BsmtExposure  \
# 125         0.0         0.0  No Basement  No Basement  No Basement
# 133         0.0         0.0  No Basement  No Basement  No Basement
# 269         0.0         0.0  No Basement  No Basement  No Basement
# 318         0.0         0.0  No Basement  No Basement  No Basement
# 354         0.0         0.0  No Basement  No Basement  No Basement
#
#     BsmtFinType1 BsmtFinType2  BsmtHalfBath  BsmtFullBath  TotalBsmtSF  \
# 125  No Basement  No Basement           0.0           0.0          0.0
# 133  No Basement  No Basement           0.0           0.0          0.0
# 269  No Basement  No Basement           0.0           0.0          0.0
# 318  No Basement  No Basement           0.0           0.0          0.0
# 354  No Basement  No Basement           0.0           0.0          0.0
#
#      BsmtUnfSF
# 125        0.0
# 133        0.0
# 269        0.0
# 318        0.0
# 354        0.0

# %%
# Based on above observation when there is no basement then BsmtFinSF1,BsmtFinSF2,BsmtUnfSF,TotalBsmtSF,BsmtFullBath 
# and BsmtHalfBath are 0 

test['BsmtFinSF1']=test.BsmtFinSF1.apply(lambda x: 0 if pd.isnull(x) else x)
test['BsmtFinSF2']=test.BsmtFinSF2.apply(lambda x: 0 if pd.isnull(x) else x)
test['BsmtHalfBath']=test.BsmtHalfBath.apply(lambda x: 0 if pd.isnull(x) else x)
test['BsmtFullBath']=test.BsmtFullBath.apply(lambda x: 0 if pd.isnull(x) else x)
test['TotalBsmtSF']=test.TotalBsmtSF.apply(lambda x: 0 if pd.isnull(x) else x)
test['BsmtUnfSF']=test.BsmtUnfSF.apply(lambda x: 0 if pd.isnull(x) else x)

# %%
test.loc[test.KitchenQual.isnull(),['KitchenAbvGr','KitchenQual']]
# Out:
#     KitchenAbvGr KitchenQual
# 95             1         NaN

# %%
kitchen_group=test.groupby(['KitchenAbvGr','KitchenQual']).count()['Id']
kitchen_group.loc[1]
# Out:
# KitchenQual
# Ex    105
# Fa     27
# Gd    563
# TA    697
# Name: Id, dtype: int64

# %%
# Based on above observation NA in KitchenQual is filled with 'TA'

test['KitchenQual']=test.KitchenQual.apply(lambda x: 'TA' if pd.isnull(x) else x)

# %%
# As see in feature description. Its give assume Typical unless deduction is warranted

test['Functional']=test.Functional.apply(lambda x:'Typ' if pd.isnull(x) else x)

# %%
test.loc[test.MSZoning.isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street     Alley  \
# 455   1916          30      NaN        109.0    21780   Grvl  No Alley
# 756   2217          20      NaN         80.0    14584   Pave  No Alley
# 790   2251          70      NaN         67.0    56600   Pave  No Alley
# 1444  2905          20      NaN        125.0    31250   Pave  No Alley
#
#      LotShape LandContour Utilities  ... ScreenPorch PoolArea   PoolQC  \
# 455       Reg         Lvl    AllPub  ...           0        0  No Pool
# 756       Reg         Low    AllPub  ...           0        0  No Pool
# 790       IR1         Low    AllPub  ...           0        0  No Pool
# 1444      Reg         Lvl    AllPub  ...           0        0  No Pool
#
#          Fence     MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 455   No Fence  No MiscFeature       0      3    2009     ConLD         Normal
# 756   No Fence  No MiscFeature       0      2    2008        WD        Abnorml
# ...

# %%
test.groupby(['MSSubClass','MSZoning']).count()['Id']
# Out:
# MSSubClass  MSZoning
# 20          C (all)       1
#             FV           21
#             RH            1
#             RL          508
#             RM           10
# 30          C (all)       6
#             RH            1
#             RL           28
#             RM           34
# 40          RL            2
# 45          RL            2
#             RM            4
# 50          C (all)       3
#             RH            1
#             RL           71
#             RM           68
# 60          FV           18
#             RL          256
#             RM            2
# 70          C (all)       3
#             RL           27
#             RM           37
# 75          RL            3
#             RM            4
# 80          RL           57
#             RM            3
# 85          RL           27
#             RM            1
# 90          RH            1
#             RL           49
#             RM            7
# 120         FV           14
# ...

# %%
# Based on above observation highest mode for MSZoning in MSSubClass 20 is RL, 30 is RM and 70 is RM

test['MSZoning']=test[['MSZoning','MSSubClass']].apply(lambda x: 'RM' if (pd.isnull(x['MSZoning']) and (x['MSSubClass']==30))
                                                                                  or (pd.isnull(x['MSZoning']) and (x['MSSubClass']==70))
                                                      else 'RL' if pd.isnull(x['MSZoning']) and (x['MSSubClass']==20) else x,axis=1)

# %% [markdown]
# # Outlier Detection and Handling

# %% [markdown]
# #### Train Data

# %%
column=[]
outlier_count=[]
non_outlier_count=[]
lower_limit=[]
upper_limit=[]
for c in train.select_dtypes([np.number]).columns:
    upper,lower=(train[c].mean()+train[c].std()*3),(train[c].mean()-train[c].std()*3)
    outlier=len([x for x in train[c] if x<lower or x>upper])
    non_outlier=len([x for x in train[c] if x>=lower and x<=upper])
    column.append(c)
    outlier_count.append(outlier)
    non_outlier_count.append(non_outlier)
    lower_limit.append(lower)
    upper_limit.append(upper)
outlier_dict=dict()
outlier_dict['column']=column
outlier_dict['outlier_count']=outlier_count
outlier_dict['non_outlier_count']=non_outlier_count
outlier_dict['lower_limit']=lower_limit
outlier_dict['upper_limit']=upper_limit

outlier=pd.DataFrame(outlier_dict)
outlier
# Out:
#            column  outlier_count  non_outlier_count   lower_limit  \
# 0              Id              0               1460   -534.330028
# 1      MSSubClass             30               1430    -70.004453
# 2     LotFrontage             16               1444      3.780667
# 3         LotArea             13               1447 -19426.966715
# 4     OverallQual              2               1458      1.950325
# 5     OverallCond             28               1432      2.236944
# 6       YearBuilt              6               1454   1880.659096
# 7    YearRemodAdd              0               1460   1922.929533
# 8      MasVnrArea             32               1428   -439.076997
# 9      BsmtFinSF1              6               1454   -924.654546
# 10     BsmtFinSF2             50               1410   -437.408503
# 11      BsmtUnfSF             11               1449   -758.360455
# 12    TotalBsmtSF             10               1450   -258.686521
# ...

# %%
def outlier_treatment(df,columns):
    for col in columns:
        lower_limit=(outlier[(outlier.column==col)]['lower_limit'].values)[0]
        upper_limit=(outlier[(outlier.column==col)]['upper_limit'].values)[0]
        df[col]=np.where(df[col]>upper_limit,upper_limit,df[col])
        df[col]=np.where(df[col]<lower_limit,lower_limit,df[col])

cols=[x for x in outlier.loc[(outlier.outlier_count>0) & (outlier.upper_limit>20),'column']]
outlier_treatment(train,cols)

# %% [markdown]
# #### Test Data

# %%
column=[]
outlier_count=[]
non_outlier_count=[]
lower_limit=[]
upper_limit=[]
for c in test.select_dtypes([np.number]).columns:
    upper,lower=(test[c].mean()+test[c].std()*3),(test[c].mean()-test[c].std()*3)
    outlier=len([x for x in test[c] if x<lower or x>upper])
    non_outlier=len([x for x in test[c] if x>=lower and x<=upper])
    column.append(c)
    outlier_count.append(outlier)
    non_outlier_count.append(non_outlier)
    lower_limit.append(lower)
    upper_limit.append(upper)
outlier_dict=dict()
outlier_dict['column']=column
outlier_dict['outlier_count']=outlier_count
outlier_dict['non_outlier_count']=non_outlier_count
outlier_dict['lower_limit']=lower_limit
outlier_dict['upper_limit']=upper_limit

outlier=pd.DataFrame(outlier_dict)
outlier
# Out:
#            column  outlier_count  non_outlier_count  lower_limit   upper_limit
# 0              Id              0               1459   926.035997   3453.964003
# 1      MSSubClass             31               1428   -70.862298    185.618980
# 2     LotFrontage             13               1446     6.626843    130.042109
# 3         LotArea             17               1442 -5047.390912  24685.713050
# 4     OverallQual              2               1457     1.768386     10.389256
# 5     OverallCond             30               1429     2.212585      8.895023
# 6       YearBuilt              2               1457  1880.187567   2062.527992
# 7    YearRemodAdd              0               1459  1920.271382   2047.054183
# 8      MasVnrArea             32               1427  -431.331626    630.679124
# 9      BsmtFinSF1             10               1449  -926.868683   1804.674029
# 10     BsmtFinSF2             52               1407  -477.512736    582.679288
# ...

# %%
def outlier_treatment(df,columns):
    for col in columns:
        lower_limit=(outlier[(outlier.column==col)]['lower_limit'].values)[0]
        upper_limit=(outlier[(outlier.column==col)]['upper_limit'].values)[0]
        df[col]=np.where(df[col]>upper_limit,upper_limit,df[col])
        df[col]=np.where(df[col]<lower_limit,lower_limit,df[col])

cols=[x for x in outlier.loc[(outlier.outlier_count>0) & (outlier.upper_limit>20),'column']]
outlier_treatment(test,cols)

# %% [markdown]
# # Correlation Matrix

# %%
corr_mat=train.corr()
fig=plt.subplots(figsize=(30,30))
sns.heatmap(corr_mat,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# After analyzing the corelation matrix, we have the following observation-
# 1. Corr between 1stFlrSF and TotalBsmtSF is 0.81, hence we can keep one among them
# 2. Corr between TotRmsAbvGrd and GrLivArea is 0.82, hence we can keep one among them
# 3. Corr between GarageCars and GarageArea is 0.88, hence we can keep one among them
# 4. Corr between GrLivArea and 2ndFlrSF is 0.68, hence we can keep one among them
# 5. Corr between TotRmsAbvGrd and 2ndFlrSF is 0.61, hence we can keep one among them
# 6. Corr between HalfBath and 2ndFlrSF is 0.60, hence we can keep one among them
# 7. Corr between FullBath and GrLivArea is 0.63, hence we can keep one among them
# 8. Corr between BsmtFullBath and BsmtFinSF1 is 0.64, hence we can keep one among them
# 9. Corr between TotRmsAbvGrd and BedroomAbvGr is 0.67, hence we can keep one among them
# 10. Corr between GarageCars and OverallQual is 0.60, hence we can keep one among them

# %% [markdown]
# # Exploratory Data Analysis

# %%
plots_list=[train.select_dtypes([np.number]).columns.sort_values().tolist()[i:i + 5] for i in range(0, len(train.select_dtypes([np.number]).columns.sort_values().tolist()), 5)] 
for i in plots_list:
    sns.pairplot(train,diag_kind='kde',y_vars=['SalePrice'],x_vars=i)

# %%
plotlist=[train.select_dtypes([object]).columns.sort_values().tolist()[i:i + 4] for i in 
            range(0, len(train.select_dtypes([object]).columns.sort_values().tolist()), 4)]
width=.35
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,10))
for i,j,k in zip(plotlist[0],ax.flat,ax.flat):
    x=np.arange(len(train.groupby([i]).count().sort_values(i)['SalePrice'].index))
    k=j.twinx()
    j.get_shared_x_axes().join(j, k)
    j.bar(x - width/2,train.groupby([i]).count().sort_values(i)['SalePrice'].values, width, label='Count',color='C0')
    k.bar(x + width/2,train.groupby([i]).mean().sort_values(i)['SalePrice'].values, width, label='SalePrice',color='C1')

    j.set_xticks(x)
    j.set_xticklabels(train.groupby([i]).count().sort_values(i)['SalePrice'].index)
    j.set_ylabel('Counts')
    k.set_ylabel('Price')
    j.set_title(i)
    for p in j.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        j.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
    for p in k.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        k.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
fig.tight_layout()

# %% [markdown]
# **Observations**
# - Most of the houses dont have an alley and the price is high for such houses.
# - Most of houses have a single family detached type dwelling and price of such house is high followed by Townhouse End Unit.
# - Most of the house have typical basement condition but houses with good basement condition cost more.
# - Most of the houses dont have exposed basement but houses with good exposure cost more

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,7))
for i,j in zip(plotlist[1],ax.flat):
    x=np.arange(len(train.groupby([i]).count().sort_values(i)['SalePrice'].index))
    k=j.twinx()
    j.get_shared_x_axes().join(j, k)
    j.bar(x - width/2,train.groupby([i]).count().sort_values(i)['SalePrice'].values, width, label='Count',color='C0')
    k.bar(x + width/2,train.groupby([i]).mean().sort_values(i)['SalePrice'].values, width, label='SalePrice',color='C1')

    j.set_xticks(x)
    j.set_xticklabels(train.groupby([i]).count().sort_values(i)['SalePrice'].index)
    j.set_ylabel('Counts')
    k.set_ylabel('Price')
    j.set_title(i)
    for p in j.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        j.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
    for p in k.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        k.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
fig.tight_layout()

# %% [markdown]
# **Observations**
# - 29% of the houses unfinished basement and 30% of the houses have Good Quality basement finish.Houses with Good Quality basement finish have high mean price.
# - Most of houses have typical or good qulity basement. But price of excellent basement quality is high.
# - Most of the house dont have secon basement finish type.
# - Most of the houses have central air.

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,7))
for i,j in zip(plotlist[2],ax.flat):
    x=np.arange(len(train.groupby([i]).count().sort_values(i)['SalePrice'].index))
    k=j.twinx()
    j.get_shared_x_axes().join(j, k)
    j.bar(x - width/2,train.groupby([i]).count().sort_values(i)['SalePrice'].values, width, label='Count',color='C0')
    k.bar(x + width/2,train.groupby([i]).mean().sort_values(i)['SalePrice'].values, width, label='SalePrice',color='C1')

    j.set_xticks(x)
    j.set_xticklabels(train.groupby([i]).count().sort_values(i)['SalePrice'].index)
    j.set_ylabel('Counts')
    k.set_ylabel('Price')
    j.set_title(i)
    for p in j.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        j.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
    for p in k.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        k.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
fig.tight_layout()

# %% [markdown]
# **Observations**
# - More than 90% of the houses are in normal condition and houses with Adjacent to postive off-site feature are more costly.
# - Most of houses have Standard Circuit Breakers & Romex electrical and the price is high for such houses.
# - Most of the house have typical exterior condition but houses with excellent exterior condition cost more.

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,7))
for i,j in zip(plotlist[3],ax.flat):
    x=np.arange(len(train.groupby([i]).count().sort_values(i)['SalePrice'].index))
    k=j.twinx()
    j.get_shared_x_axes().join(j, k)
    j.bar(x - width/2,train.groupby([i]).count().sort_values(i)['SalePrice'].values, width, label='Count',color='C0')
    k.bar(x + width/2,train.groupby([i]).mean().sort_values(i)['SalePrice'].values, width, label='SalePrice',color='C1')

    j.set_xticks(x)
    if i in ['Exterior1st','Exterior2nd']:
        j.set_xticklabels(train.groupby([i]).count().sort_values(i)['SalePrice'].index,rotation=45)
    else:
        j.set_xticklabels(train.groupby([i]).count().sort_values(i)['SalePrice'].index)
    j.set_ylabel('Counts')
    k.set_ylabel('Price')
    j.set_title(i)
    for p in j.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        j.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
    for p in k.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        k.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
fig.tight_layout()

# %% [markdown]
# **Observations**
# - Most of the huses have vinyl siding for exterior 1 and 2.
# - Most of houses have typical exterior quality. But price of excellent exterior quality is high.
# - Most of the houses dont have fence and he price is high for such houses. It shows fence is not a neccissity for a house.

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,7))
for i,j in zip(plotlist[4],ax.flat):
    x=np.arange(len(train.groupby([i]).count().sort_values(i)['SalePrice'].index))
    k=j.twinx()
    j.get_shared_x_axes().join(j, k)
    j.bar(x - width/2,train.groupby([i]).count().sort_values(i)['SalePrice'].values, width, label='Count',color='C0')
    k.bar(x + width/2,train.groupby([i]).mean().sort_values(i)['SalePrice'].values, width, label='SalePrice',color='C1')

    j.set_xticks(x)
    j.set_xticklabels(train.groupby([i]).count().sort_values(i)['SalePrice'].index)
    j.set_ylabel('Counts')
    k.set_ylabel('Price')
    j.set_title(i)
    for p in j.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        j.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
    for p in k.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        k.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
fig.tight_layout()

# %% [markdown]
# **Observations**
# - Most of the huses dont have fireplace and they have low price showing firplac is necessary for a house. Houses ith excellent firplace quality have high price.
# - Most of houses have poured concrete or cinder block foundation and poured concrete foundation houses cost more
# - Most of the houses dhave typical functionanlity and they cost more
# - Most of the houses have typical garage condition and they cost high and houses with no garage cost low.

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,7))
for i,j in zip(plotlist[5],ax.flat):
    x=np.arange(len(train.groupby([i]).count().sort_values(i)['SalePrice'].index))
    k=j.twinx()
    j.get_shared_x_axes().join(j, k)
    j.bar(x - width/2,train.groupby([i]).count().sort_values(i)['SalePrice'].values, width, label='Count',color='C0')
    k.bar(x + width/2,train.groupby([i]).mean().sort_values(i)['SalePrice'].values, width, label='SalePrice',color='C1')

    j.set_xticks(x)
    j.set_xticklabels(train.groupby([i]).count().sort_values(i)['SalePrice'].index)
    j.set_ylabel('Counts')
    k.set_ylabel('Price')
    j.set_title(i)
    for p in j.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        j.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
    for p in k.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        k.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
fig.tight_layout()

# %% [markdown]
# **Observations**
# - Most of the houses have gas forced warm air furnace heating and they cost high.
# - Excellent quality garages cost high but most houses have typical garange quality.
# - Most of the houses have garage attached to them and they cost high.
# - Most of the houses have unfinished garage but houses with finished garage cost higher and houses with no garage cost low.

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,7))
for i,j in zip(plotlist[6],ax.flat):
    x=np.arange(len(train.groupby([i]).count().sort_values(i)['SalePrice'].index))
    k=j.twinx()
    j.get_shared_x_axes().join(j, k)
    j.bar(x - width/2,train.groupby([i]).count().sort_values(i)['SalePrice'].values, width, label='Count',color='C0')
    k.bar(x + width/2,train.groupby([i]).mean().sort_values(i)['SalePrice'].values, width, label='SalePrice',color='C1')

    j.set_xticks(x)
    j.set_xticklabels(train.groupby([i]).count().sort_values(i)['SalePrice'].index)
    j.set_ylabel('Counts')
    k.set_ylabel('Price')
    j.set_title(i)
    for p in j.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        j.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
    for p in k.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        k.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
fig.tight_layout()

# %% [markdown]
# **Observations**
# - Most of the houses have excellent heaing quality and they cost high.
# - Most of houses have 1 story but houses with 2.5 story cost more.
# - Most of the houses have typical or good quality kitchen but houses with excellent kitchen quality cost more.
# - Most of the houses have flat land contour but hillside houses cost more.

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,7))
for i,j in zip(plotlist[7],ax.flat):
    x=np.arange(len(train.groupby([i]).count().sort_values(i)['SalePrice'].index))
    k=j.twinx()
    j.get_shared_x_axes().join(j, k)
    j.bar(x - width/2,train.groupby([i]).count().sort_values(i)['SalePrice'].values, width, label='Count',color='C0')
    k.bar(x + width/2,train.groupby([i]).mean().sort_values(i)['SalePrice'].values, width, label='SalePrice',color='C1')

    j.set_xticks(x)
    j.set_xticklabels(train.groupby([i]).count().sort_values(i)['SalePrice'].index)
    j.set_ylabel('Counts')
    k.set_ylabel('Price')
    j.set_title(i)
    for p in j.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        j.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
    for p in k.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        k.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
fig.tight_layout()

# %% [markdown]
# **Observations**
# - Most of the houses have gentle slope and cost low. Severe slope houses cost more
# - Floating village residential houses cost more but have less availbility.
# - Regular lot shapes are more in quantity but low price.

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,7))
for i,j in zip(plotlist[8],ax.flat):
    x=np.arange(len(train.groupby([i]).count().sort_values(i)['SalePrice'].index))
    k=j.twinx()
    j.get_shared_x_axes().join(j, k)
    j.bar(x - width/2,train.groupby([i]).count().sort_values(i)['SalePrice'].values, width, label='Count',color='C0')
    k.bar(x + width/2,train.groupby([i]).mean().sort_values(i)['SalePrice'].values, width, label='SalePrice',color='C1')

    j.set_xticks(x)
    if i=='Neighborhood':
        j.set_xticklabels(train.groupby([i]).count().sort_values(i)['SalePrice'].index,rotation=45)
    else:
        j.set_xticklabels(train.groupby([i]).count().sort_values(i)['SalePrice'].index)
    j.set_ylabel('Counts')
    k.set_ylabel('Price')
    j.set_title(i)
    for p in j.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        j.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
    for p in k.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        k.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
fig.tight_layout()

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,7))
for i,j in zip(plotlist[9],ax.flat):
    x=np.arange(len(train.groupby([i]).count().sort_values(i)['SalePrice'].index))
    k=j.twinx()
    j.get_shared_x_axes().join(j, k)
    j.bar(x - width/2,train.groupby([i]).count().sort_values(i)['SalePrice'].values, width, label='Count',color='C0')
    k.bar(x + width/2,train.groupby([i]).mean().sort_values(i)['SalePrice'].values, width, label='SalePrice',color='C1')

    j.set_xticks(x)
    j.set_xticklabels(train.groupby([i]).count().sort_values(i)['SalePrice'].index)
    j.set_ylabel('Counts')
    k.set_ylabel('Price')
    j.set_title(i)
    for p in j.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        j.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
    for p in k.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        k.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
fig.tight_layout()

# %% [markdown]
# **Observations**
# - Most of the houses dont have pool and they have low price showing pool is necessary for a house. Houses with excellent pool quality have high price.
# - Most of houses have copoite shingles for roof. Wood shingles roof cost more.

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,7))
for i,j in zip(plotlist[10],ax.flat):
    x=np.arange(len(train.groupby([i]).count().sort_values(i)['SalePrice'].index))
    k=j.twinx()
    j.get_shared_x_axes().join(j, k)
    j.bar(x - width/2,train.groupby([i]).count().sort_values(i)['SalePrice'].values, width, label='Count',color='C0')
    k.bar(x + width/2,train.groupby([i]).mean().sort_values(i)['SalePrice'].values, width, label='SalePrice',color='C1')

    j.set_xticks(x)
    j.set_xticklabels(train.groupby([i]).count().sort_values(i)['SalePrice'].index)
    j.set_ylabel('Counts')
    k.set_ylabel('Price')
    j.set_title(i)
    for p in j.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        j.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)
    for p in k.patches:
        h = p.get_height()
        x = p.get_x()+p.get_width()/2
        k.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,2),textcoords="offset points", ha="center", va="bottom",
                  fontsize=8)

fig.delaxes(ax[1][1])
fig.tight_layout()

# %% [markdown]
# **Observations**
# - Most of the houses have paved street.
# - Most of houses have all public utilities

# %%
fig,ax=plt.subplots(figsize=(15,7),ncols=2)
sns.distplot(a=train['SalePrice'],ax=ax[0])
sns.distplot(a=np.log1p(train['SalePrice']),ax=ax[1])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %% [markdown]
# # Feature Engineering

# %%
test['HouseStyle']=test.HouseStyle.apply(lambda x: 1 if re.split('[SLFU]',x)[0]=='' else re.split('[SLFU]',x)[0])
test['HouseStyle']=test.HouseStyle.astype('float64')
train['HouseStyle']=train.HouseStyle.apply(lambda x: 1 if re.split('[SLFU]',x)[0]=='' else re.split('[SLFU]',x)[0])
train['HouseStyle']=train.HouseStyle.astype('float64')

# %%
train['OverallQC']=(train['OverallQual']+train['OverallCond'])/4
train['ExterQual']=train.ExterQual.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' else 1)
train['ExterCond']=train.ExterCond.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' else 1)
train['ExterQC']=(train['ExterQual']+train['ExterCond'])/2
train['HeatingQC']=train.HeatingQC.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' else 1)
train['CentralAir']=train.CentralAir.apply(lambda x: 1 if x=='Yes' else 0)
train['KitchenQual']=train.KitchenQual.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' else 1)
train['GarageQual']=train.GarageQual.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' 
                                           else 1 if x=='Po' else 0)
train['GarageCond']=train.GarageCond.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' 
                                           else 1 if x=='Po' else 0)
train['GarageQC']=(train['GarageQual']+train['GarageCond'])/2
train['BsmtQual']=train.BsmtQual.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' 
                                           else 1 if x=='Po' else 0)
train['BsmtCond']=train.BsmtCond.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' 
                                           else 1 if x=='Po' else 0)
train['BsmtQC']=(train['BsmtQual']+train['BsmtCond'])/2
train['PoolQC']=train.PoolQC.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' 
                                           else 0)
train['FireplaceQu']=train.FireplaceQu.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' 
                                           else 1 if x=='Po' else 0)
train['BsmtExposure']=train.BsmtExposure.apply(lambda x: 4 if x=='Gd' else 3 if x=='Av' else 2 if x =='Mn' 
                                           else 1 if x=='No' else 0)

# %%
test['OverallQC']=(test['OverallQual']+test['OverallCond'])/4
test['ExterQual']=test.ExterQual.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' else 1)
test['ExterCond']=test.ExterCond.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' else 1)
test['ExterQC']=(test['ExterQual']+test['ExterCond'])/2
test['HeatingQC']=test.HeatingQC.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' else 1)
test['CentralAir']=test.CentralAir.apply(lambda x: 1 if x=='Yes' else 0)
test['KitchenQual']=test.KitchenQual.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' else 1)
test['GarageQual']=test.GarageQual.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' 
                                           else 1 if x=='Po' else 0)
test['GarageCond']=test.GarageCond.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' 
                                           else 1 if x=='Po' else 0)
test['GarageQC']=(test['GarageQual']+test['GarageCond'])/2
test['BsmtQual']=test.BsmtQual.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' 
                                           else 1 if x=='Po' else 0)
test['BsmtCond']=test.BsmtCond.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' 
                                           else 1 if x=='Po' else 0)
test['BsmtQC']=(test['BsmtQual']+test['BsmtCond'])/2
test['PoolQC']=test.PoolQC.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' 
                                           else 0)
test['FireplaceQu']=test.FireplaceQu.apply(lambda x: 5 if x=='Ex' else 4 if x=='Gd' else 3 if x=='TA' else 2 if x =='Fa' 
                                           else 1 if x=='Po' else 0)
test['BsmtExposure']=test.BsmtExposure.apply(lambda x: 4 if x=='Gd' else 3 if x=='Av' else 2 if x =='Mn' 
                                           else 1 if x=='No' else 0)

# %%
train['haspool']=train.PoolArea.apply(lambda x: 0 if x==0 else 1)
train['hasfireplace']=train.Fireplaces.apply(lambda x: 0 if x==0 else 1)
train['hasfence']=train.Fence.apply(lambda x: 0 if x=='No Fence' else 1)
train['hasbasement']=train.BsmtFinType1.apply(lambda x: 0 if x=='No Basement' else 1)
train['hasgarage']=train.GarageArea.apply(lambda x: 0 if x==0 else 1)
train['totalporch']=train['WoodDeckSF']+train['OpenPorchSF']+train['EnclosedPorch']+train['3SsnPorch']+train['ScreenPorch']
train['GarageYrBlt']=train['GarageYrBlt'].astype('int64')
train['YearBuilt']=train['YearBuilt'].astype('int64')
train['ageofhouse']=train['YrSold']-train['YearBuilt']
train['ageofgarage']=train['YrSold']-train['GarageYrBlt']

# %%
test['haspool']=test.PoolArea.apply(lambda x: 0 if x==0 else 1)
test['hasfireplace']=test.Fireplaces.apply(lambda x: 0 if x==0 else 1)
test['hasfence']=test.Fence.apply(lambda x: 0 if x=='No Fence' else 1)
test['hasbasement']=test.BsmtFinType1.apply(lambda x: 0 if x=='No Basement' else 1)
test['hasgarage']=test.GarageArea.apply(lambda x: 0 if x==0 else 1)
test['totalporch']=test['WoodDeckSF']+test['OpenPorchSF']+test['EnclosedPorch']+test['3SsnPorch']+test['ScreenPorch']
test['GarageYrBlt']=test['GarageYrBlt'].astype('int64')
test['YearBuilt']=test['YearBuilt'].astype('int64')
test['ageofhouse']=test['YrSold']-test['YearBuilt']
test['ageofgarage']=test['YrSold']-test['GarageYrBlt']

# %%
train['SalePriceLog']=np.log1p(train['SalePrice'])

# %% [markdown]
# # Model Building and Selection

# %%
drop=['SalePrice','Id','SalePriceLog','TotRmsAbvGrd','GarageCars','1stFlrSF','OverallCond','OverallQual',
     'ExterQual','BsmtCond','BsmtQual','GarageQual','GarageCond','ExterCond','GarageYrBlt','YearBuilt','BsmtFullBath',
      'FullBath','2ndFlrSF']
x=train[[x for x in train.columns if x not in drop]]
y=train[['SalePriceLog']]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=1)

# %%
ct=ColumnTransformer([('ohe',OneHotEncoder(sparse=False, handle_unknown='ignore'),
                       ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
       'MasVnrType', 'Foundation', 'BsmtFinType1', 'BsmtFinType2', 'Heating',
       'Electrical', 'Functional', 'GarageType', 'GarageFinish', 'PavedDrive',
       'Fence', 'MiscFeature', 'SaleType', 'SaleCondition'])],remainder='passthrough')

# %%
models=[LinearRegression(), Lasso(random_state=1),Ridge(random_state=1),DecisionTreeRegressor(random_state=1)]
scales=[RobustScaler(),StandardScaler(),Normalizer(),MinMaxScaler()]
result=[]
for model in models:
    final=[]
    for scale in scales:
        pipe=Pipeline([('ct',ct),('scale',scale),('model',model)])
        score=cross_val_score(estimator=pipe,X=x_train,y=np.array(y_train).ravel(),cv=5,n_jobs=-1,scoring='r2').mean()
        final.append(round(score*100,2))
    result.append(final)
base_result=pd.DataFrame(result,index=['Linear Regression','Lasso','Ridge', 'Decision Tree Regression'],
             columns=['Robust Scaler','Standard Scaler','Normalizer','Min Max Scaler'])
base_result
# Out:
#                           Robust Scaler  Standard Scaler    Normalizer  \
# Linear Regression         -5.163543e+18    -6.816952e+26 -3.994716e+16
# Lasso                      3.440000e+00    -1.000000e-01 -1.000000e-01
# Ridge                      8.827000e+01     8.742000e+01  6.231000e+01
# Decision Tree Regression   7.158000e+01     7.158000e+01  5.169000e+01
#
#                           Min Max Scaler
# Linear Regression          -1.329976e+25
# Lasso                      -1.000000e-01
# Ridge                       8.830000e+01
# Decision Tree Regression    7.180000e+01

# %%
pipe=Pipeline([('ct',ct),('scale',RobustScaler()),('model',Ridge())])
pipe.fit(x_train,np.array(y_train).ravel())
y_pred=pipe.predict(x_test)
metrics_df=pd.DataFrame(data=[metrics.mean_absolute_error(y_test,y_pred),metrics.mean_squared_error(y_test,y_pred),
                              metrics.mean_squared_log_error(y_test,y_pred),metrics.r2_score(y_test,y_pred)],
                        columns=['Score'],index=['MAE','MSE','MSLE','R^2'])
metrics_df
# Out:
#          Score
# MAE   0.085586
# MSE   0.015145
# MSLE  0.000095
# R^2   0.907471

# %% [markdown]
# # Predicting House Price for Test Data

# %%
x_test=test[[x for x in test.columns if x not in drop]]

# %%
pipe=Pipeline([('ct',ct),('scale',RobustScaler()),('model',Ridge())])
pipe.fit(x,np.array(y).ravel())
y_pred=pipe.predict(x_test)

# %%
price=pd.DataFrame(y_pred,columns=['SalePrice'])
final=test.join(price)
final=final[['Id','SalePrice']]
final['SalePrice']=final['SalePrice'].apply(lambda x: np.exp(x)-1)
final
# Out:
#         Id      SalePrice
# 0     1461  119900.285733
# 1     1462  158256.765692
# 2     1463  182150.848356
# 3     1464  204108.638822
# 4     1465  193167.612362
# ...    ...            ...
# 1454  2915   84325.014453
# 1455  2916   81731.145661
# 1456  2917  175604.187264
# 1457  2918  113597.939564
# 1458  2919  222560.918541
#
# [1459 rows x 2 columns]

# %%
final.to_csv('Submission.csv',index=False)
